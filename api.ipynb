# %%
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
res=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=6b591f30e2e98b7babae6651a30b63e9&language=en-US&page=1')

# %%
df=pd.DataFrame(res.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     46.2770
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     42.1371
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     27.5151
# 3  The true story of how businessman Oskar Schind...   1993-12-15     28.0741
# 4  The defense and the prosecution have rested an...   1957-04-10     19.8707
#
#    vote_average  vote_count
# 0         8.700       30192
# 1         8.700       22805
# 2         8.572       13827
# 3         8.600       17356
# 4         8.600        9912

# %%
df =pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# all_data = []

# for i in range(1, 542):
#     res = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=6b591f30e2e98b7babae6651a30b63e9&language=en-US&page={i}')
    
#     temp_df = pd.DataFrame(res.json()['results'])[
#         ['id','title','overview','release_date','popularity','vote_average','vote_count']
#     ]
    
#     all_data.append(temp_df)

# # ek baar me combine karo
# df = pd.concat(all_data, ignore_index=True)

# %%
import pandas as pd
import requests
from concurrent.futures import ThreadPoolExecutor

API_KEY = "6b591f30e2e98b7babae6651a30b63e9"

def fetch_page(i):
    url = f'https://api.themoviedb.org/3/movie/top_rated?api_key={API_KEY}&language=en-US&page={i}'
    res = requests.get(url)
    data = res.json()
    
    if 'results' in data:
        return pd.DataFrame(data['results'])[
            ['id','title','overview','release_date','popularity','vote_average','vote_count']
        ]
    return pd.DataFrame()

# parallel execution
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(fetch_page, range(1, 542)))

df = pd.concat(results, ignore_index=True)
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 9995  343173                The Rezort
# 9996   46441                 Mirrors 2
# 9997   13160        Over Her Dead Body
# 9998   12121           Made in America
# 9999    9271                Virtuosity
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (10000, 7)

# %%
df.to_csv("top_rated_movie.csv")
