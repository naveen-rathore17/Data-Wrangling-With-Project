# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
webpage=requests.get('https://jobhub-1xq3.onrender.com/jobs').text
soup = BeautifulSoup(webpage, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Jobs | JobHub
#   </title>
#   <link href="images/jobhub_favicon.ico" rel="icon" type="image/x-icon"/>
#   <script src="https://cdn.tailwindcss.com">
#   </script>
#  </head>
#  <body class="min-h-screen flex flex-col overflow-x-hidden relative">
#   <!-- Background Image -->
#   <div class="absolute inset-0 -z-10">
#    <img class="w-full h-full object-cover opacity-40" src="https://wallpapershome.com/images/pages/pic_h/26421.jpg"/>
#   </div>
#   <!-- Gradient Dark Overlay (IMPORTANT) -->
#   <div class="absolute inset-0 -z-10 bg-gradient-to-br from-black/80 via-black/60 to-black/80">
#   </div>
#   <!-- HEADER -->
#   <nav class="bg-white/95 backdrop-blur-lg shadow-sm sticky top-0 z-50 border-b">
#    <div class="max-w-7xl mx-auto px-6 py-3 flex justify-between items-center">
#     <!-- LOGO -->
# ...

# %%
for i in soup.find_all('p'):
  print(i.get_text(strip=True))
# Out:
# Find opportunities that match your skills
# 🏢 Infosys Tech
# 📍 Pune, Maharashtra
# 🏢 Wipro
# 📍 Bengaluru, Karnataka
# 🏢 TechNova Solutions
# 📍 Delhi
# 🏢  CodeCraft Pvt Ltd
# 📍 Bangalore
# 🏢 PixelForge Studio
# 📍 Mumbai
# 🏢 NextGen Technologies
# 📍 Hyderabad
# 🏢 Insight Analytics
# 📍 Pune
# 🏢 QualitySoft Systems
# 📍 Chennai
# 🏢 Perfozi-Tech
# 📍 Ahemdabad
# 🏢 Perfozi-Tech
# 📍 Jaipur, Rajasthan
# 🏢 AU Small Finance Bank
# 📍 Jaipur, Rajasthan
# 🏢 Sigma Minerals Limited
# 📍 Jodhpur, Rajasthan
# Daily new opportunities
# Apply in just one click
# Your data is safe
# © 2026 JobPortal. All rights reserved.
# Are you sure you want to logout?
